# %%
database = {"Name":"haridha","Age":23,"DOB":"6th Jan","Place":"Chennai"}

# %%
database.keys()
# Out:
# dict_keys(['Name', 'Age', 'DOB', 'Place'])

# %%
database.values()
# Out:
# dict_values(['haridha', 23, '6th Jan', 'Chennai'])

# %%
database.copy()
database
# Out:
# {'Age': 23, 'DOB': '6th Jan', 'Name': 'haridha', 'Place': 'Chennai'}

# %%
x=('Native','Education','Profession')
y=0
dict.fromkeys(x,y)
# Out:
# {'Education': 0, 'Native': 0, 'Profession': 0}

# %%
database.items()
# Out:
# dict_items([('Name', 'haridha'), ('Age', 23), ('DOB', '6th Jan'), ('Place', 'Chennai')])

# %%
database.update({'Profession':'Software Developer'})

# %%
database
# Out:
# {'Age': 23,
#  'DOB': '6th Jan',
#  'Name': 'haridha',
#  'Place': 'Chennai',
#  'Profession': 'Software Developer'}

# %%
database.setdefault("Native","Vellore")
# Out:
# 'Vellore'

# %%
database
# Out:
# {'Age': 23,
#  'DOB': '6th Jan',
#  'Name': 'haridha',
#  'Native': 'Vellore',
#  'Place': 'Chennai',
#  'Profession': 'Software Developer'}

# %%
database.get("Name")
# Out:
# 'haridha'

# %%
database.pop("Place")
# Out:
# 'Chennai'

# %%
database
# Out:
# {'Age': 23,
#  'DOB': '6th Jan',
#  'Name': 'haridha',
#  'Native': 'Vellore',
#  'Profession': 'Software Developer'}

# %%
database.popitem()
# Out:
# ('Native', 'Vellore')

# %%
database
# Out:
# {'Age': 23,
#  'DOB': '6th Jan',
#  'Name': 'haridha',
#  'Profession': 'Software Developer'}

# %%
database.clear()

# %%
database
# Out:
# {}
